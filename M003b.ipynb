# %% [markdown]
# ## Datenbank

# %%
import pyodbc
import pandas as pd
import numpy as np

# %%
connStr = "Driver={ODBC Driver 17 for SQL Server};Server=WIN11-LK3;Database=Northwind;Trusted_Connection=yes;"
connSqlServer = pyodbc.connect(connStr)

# %%
# Manuelles SQL
cursor = connSqlServer.cursor()

customers = cursor.execute("SELECT * FROM Customers").fetchall()

# %%
# Automatisch über Pandas
pd.read_sql("SELECT * FROM Customers", con=connSqlServer)
# Out:
# C:\Users\lk3\AppData\Local\Temp\ipykernel_18412\3707467764.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM Customers", con=connSqlServer)
#    CustomerID                         CompanyName              ContactName  \
# 0       ALFKI                 Alfreds Futterkiste             Maria Anders
# 1       ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2       ANTON             Antonio Moreno Taquería           Antonio Moreno
# 3       AROUT                     Around the Horn             Thomas Hardy
# 4       BERGS                  Berglunds snabbköp       Christina Berglund
# ..        ...                                 ...                      ...
# 87      WARTH                      Wartian Herkku         Pirkko Koskitalo
# ...
