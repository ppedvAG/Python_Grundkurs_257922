# %% [markdown]
# # Pandas
#
# Python Advanced Data Analysis Toolkit (Pandas)
#
# Hauptwerkzeug zur Verarbeitung von Daten

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Serie
#
# Ein Numpy Array mit zusätzlichen Eigenschaften
#
# - Benannter Index
# - Name

# %%
pd.Series([8.6, 83.7, 0.38, 9])  # Die Zahlen sagen alleine nichts aus
# Out:
# 0     8.60
# 1    83.70
# 2     0.38
# 3     9.00
# dtype: float64

# %%
einwohnerM = pd.Series([8.6, 83.7, 0.38, 9])

# %% [markdown]
# ### Name

# %%
einwohnerM.name = "Einwohnerzahlen Europa"

# %%
einwohnerM
# Out:
# 0     8.60
# 1    83.70
# 2     0.38
# 3     9.00
# Name: Einwohnerzahlen Europa, dtype: float64

# %% [markdown]
# ### Index

# %%
einwohnerM.index = ["CH", "DE", "LI", "AT"]

# %%
einwohnerM
# Out:
# CH     8.60
# DE    83.70
# LI     0.38
# AT     9.00
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM[0]  # Nicht mehr möglich
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\source\repos\Python_Grundkurs_2026_01_19\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 einwohnerM[0]  # Nicht mehr möglich
#
# File ~\source\repos\Python_Grundkurs_2026_01_19\.venv\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~\source\repos\Python_Grundkurs_2026_01_19\.venv\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~\source\repos\Python_Grundkurs_2026_01_19\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %%
einwohnerM["CH"]
# Out:
# np.float64(8.6)

# %%
einwohnerM["CH":"LI"]  # ACHTUNG: Obergrenze inkludiert
# Out:
# CH     8.60
# DE    83.70
# LI     0.38
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM.values
# Out:
# array([ 8.6 , 83.7 ,  0.38,  9.  ])

# %%
type(einwohnerM.values)  # ndarray: n-dimensional array
# Out:
# numpy.ndarray

# %%
einwohnerM.index
# Out:
# Index(['CH', 'DE', 'LI', 'AT'], dtype='str')

# %% [markdown]
# ### Vektorisierung

# %%
einwohnerM > 5
# Out:
# CH     True
# DE     True
# LI    False
# AT     True
# Name: Einwohnerzahlen Europa, dtype: bool

# %%
einwohnerM[einwohnerM > 5]
# Out:
# CH     8.6
# DE    83.7
# AT     9.0
# Name: Einwohnerzahlen Europa, dtype: float64

# %%
einwohnerM.mean()
# Out:
# np.float64(25.419999999999998)

# %%
einwohnerM[einwohnerM < einwohnerM.mean()]
# Out:
# CH    8.60
# LI    0.38
# AT    9.00
# Name: Einwohnerzahlen Europa, dtype: float64

# %% [markdown]
# ## DataFrame
#
# Effektiv eine Tabelle
#
# Generell wird ein Datenset eingelesen um ein DataFrame zu erstellen

# %%
pd.DataFrame({"Spalte1": [1, 2, 3], "Spalte2": [4, 5, 6], "Spalte3": [7, 8, 9]})
# Out:
#    Spalte1  Spalte2  Spalte3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %% [markdown]
# ### read_csv
#
# Daten aus einer CSV-Quelle einlesen
#
# Wird per Parameter konfiguriert:
# - delimiter/sep
# - thousands
# - decimal
# - parse_dates
# - index_col
# - ...

# %%
pd.read_csv("Data/PopulationData.csv", delimiter=";", thousands=",", decimal=".")
# Out:
#        # Country (or dependency)  Population(2020) YearlyChange  NetChange  \
# 0      1                   China        1439323776       0.39 %    5540090
# 1      2                   India        1380004385       0.99 %   13586631
# 2      3           United States         331002651       0.59 %    1937734
# 3      4               Indonesia         273523615       1.07 %    2898047
# 4      5                Pakistan         220892340       2.00 %    4327022
# ..   ...                     ...               ...          ...        ...
# 230  231              Montserrat              4992       0.06 %          3
# 231  232        Falkland Islands              3480       3.05 %        103
# 232  233                    Niue              1626       0.68 %         11
# 233  234                 Tokelau              1357       1.27 %         17
# 234  235           Vatican State               801       0.25 %          2
#
#      Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate Med.Age  \
# 0               153         9388211      -348399.0       1.7      38
# 1               464         2973190      -532687.0       2.2      28
# 2                36         9147420       954806.0       1.8      38
# 3               151         1811570       -98955.0       2.3      30
# 4               287          770880      -233379.0       3.6      23
# ..              ...             ...            ...       ...     ...
# 230              50             100            NaN      N.A.    N.A.
# 231               0           12170            NaN      N.A.    N.A.
# 232               6             260            NaN      N.A.    N.A.
# 233             136              10            NaN      N.A.    N.A.
# 234            2003               0            NaN      N.A.    N.A.
#
#     UrbanPop % WorldShare
# 0         61 %    18.47 %
# 1         35 %    17.70 %
# 2         83 %     4.25 %
# 3         56 %     3.51 %
# 4         35 %     2.83 %
# ..         ...        ...
# 230       10 %     0.00 %
# 231       66 %     0.00 %
# 232       46 %     0.00 %
# 233        0 %     0.00 %
# 234       N.A.     0.00 %
#
# [235 rows x 12 columns]

# %%
data = pd.read_csv("Data/PopulationData.csv", delimiter=";", thousands=",", decimal=".")

# %% [markdown]
# Überblick verschaffen

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        235 non-null    int64
#  1   Country (or dependency)  235 non-null    str
#  2   Population(2020)         235 non-null    int64
#  3   YearlyChange             235 non-null    str
#  4   NetChange                235 non-null    int64
#  5   Density(P/Km²)           235 non-null    int64
#  6   Land Area(Km²)           235 non-null    int64
#  7   Migrants(net)            201 non-null    float64
#  8   Fert.Rate                235 non-null    str
#  9   Med.Age                  235 non-null    str
#  10  UrbanPop %               235 non-null    str
#  11  WorldShare               235 non-null    str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 22.2 KB

# %% [markdown]
# ### Probleme mit dem Datenset
#
# DataFrame:
# - Schlechte Spaltennamen
# - Doppelter Index
#
# Daten selbst:
# - Prozentzeichen
# - Leere Felder (NaN)
# - N.A. (String)
# - Datentypen
# - Tausendertrennzeichen/Dezimalzeichen

# %% [markdown]
# ### Index
#
# - set_index(Spaltenname)
# - Bei read_csv mit dem Parameter index_col=
# - data.index = Liste

# %%
# WICHTIG: Die meistens Funktionen, die Änderungen erwirken, verändern nicht das originale DataFrame
# 2 Optionen: Zuweisung, inplace
data.set_index("Country (or dependency)", inplace=True)

# %%
data
# Out:
#                            #  Population(2020) YearlyChange  NetChange  \
# Country (or dependency)
# China                      1        1439323776       0.39 %    5540090
# India                      2        1380004385       0.99 %   13586631
# United States              3         331002651       0.59 %    1937734
# Indonesia                  4         273523615       1.07 %    2898047
# Pakistan                   5         220892340       2.00 %    4327022
# ...                      ...               ...          ...        ...
# Montserrat               231              4992       0.06 %          3
# Falkland Islands         232              3480       3.05 %        103
# Niue                     233              1626       0.68 %         11
# Tokelau                  234              1357       1.27 %         17
# Vatican State            235               801       0.25 %          2
#
#                          Density(P/Km²)  Land Area(Km²)  Migrants(net)  \
# Country (or dependency)
# China                               153         9388211      -348399.0
# India                               464         2973190      -532687.0
# United States                        36         9147420       954806.0
# Indonesia                           151         1811570       -98955.0
# Pakistan                            287          770880      -233379.0
# ...                                 ...             ...            ...
# Montserrat                           50             100            NaN
# Falkland Islands                      0           12170            NaN
# Niue                                  6             260            NaN
# Tokelau                             136              10            NaN
# Vatican State                      2003               0            NaN
#
#                         Fert.Rate Med.Age UrbanPop % WorldShare
# Country (or dependency)
# China                         1.7      38       61 %    18.47 %
# India                         2.2      28       35 %    17.70 %
# United States                 1.8      38       83 %     4.25 %
# Indonesia                     2.3      30       56 %     3.51 %
# Pakistan                      3.6      23       35 %     2.83 %
# ...                           ...     ...        ...        ...
# Montserrat                   N.A.    N.A.       10 %     0.00 %
# Falkland Islands             N.A.    N.A.       66 %     0.00 %
# Niue                         N.A.    N.A.       46 %     0.00 %
# Tokelau                      N.A.    N.A.        0 %     0.00 %
# Vatican State                N.A.    N.A.       N.A.     0.00 %
#
# [235 rows x 11 columns]

# %%
data.index.name = "Country"

# %%
data
# Out:
#                     #  Population(2020) YearlyChange  NetChange  \
# Country
# China               1        1439323776       0.39 %    5540090
# India               2        1380004385       0.99 %   13586631
# United States       3         331002651       0.59 %    1937734
# Indonesia           4         273523615       1.07 %    2898047
# Pakistan            5         220892340       2.00 %    4327022
# ...               ...               ...          ...        ...
# Montserrat        231              4992       0.06 %          3
# Falkland Islands  232              3480       3.05 %        103
# Niue              233              1626       0.68 %         11
# Tokelau           234              1357       1.27 %         17
# Vatican State     235               801       0.25 %          2
#
#                   Density(P/Km²)  Land Area(Km²)  Migrants(net) Fert.Rate  \
# Country
# China                        153         9388211      -348399.0       1.7
# India                        464         2973190      -532687.0       2.2
# United States                 36         9147420       954806.0       1.8
# Indonesia                    151         1811570       -98955.0       2.3
# Pakistan                     287          770880      -233379.0       3.6
# ...                          ...             ...            ...       ...
# Montserrat                    50             100            NaN      N.A.
# Falkland Islands               0           12170            NaN      N.A.
# Niue                           6             260            NaN      N.A.
# Tokelau                      136              10            NaN      N.A.
# Vatican State               2003               0            NaN      N.A.
#
#                  Med.Age UrbanPop % WorldShare
# Country
# China                 38       61 %    18.47 %
# India                 28       35 %    17.70 %
# United States         38       83 %     4.25 %
# Indonesia             30       56 %     3.51 %
# Pakistan              23       35 %     2.83 %
# ...                  ...        ...        ...
# Montserrat          N.A.       10 %     0.00 %
# Falkland Islands    N.A.       66 %     0.00 %
# Niue                N.A.       46 %     0.00 %
# Tokelau             N.A.        0 %     0.00 %
# Vatican State       N.A.       N.A.     0.00 %
#
# [235 rows x 11 columns]

# %% [markdown]
# ### Spalten bearbeiten
# - drop: Spalten löschen
# - rename: Spalten umbenennen
#
# Hier auch wieder inplace notwendig

# %%
data.drop(columns=["#"], inplace=True)

# %%
data
# Out:
#                   Population(2020) YearlyChange  NetChange  Density(P/Km²)  \
# Country
# China                   1439323776       0.39 %    5540090             153
# India                   1380004385       0.99 %   13586631             464
# United States            331002651       0.59 %    1937734              36
# Indonesia                273523615       1.07 %    2898047             151
# Pakistan                 220892340       2.00 %    4327022             287
# ...                            ...          ...        ...             ...
# Montserrat                    4992       0.06 %          3              50
# Falkland Islands              3480       3.05 %        103               0
# Niue                          1626       0.68 %         11               6
# Tokelau                       1357       1.27 %         17             136
# Vatican State                  801       0.25 %          2            2003
#
#                   Land Area(Km²)  Migrants(net) Fert.Rate Med.Age UrbanPop %  \
# Country
# China                    9388211      -348399.0       1.7      38       61 %
# India                    2973190      -532687.0       2.2      28       35 %
# United States            9147420       954806.0       1.8      38       83 %
# Indonesia                1811570       -98955.0       2.3      30       56 %
# Pakistan                  770880      -233379.0       3.6      23       35 %
# ...                          ...            ...       ...     ...        ...
# Montserrat                   100            NaN      N.A.    N.A.       10 %
# Falkland Islands           12170            NaN      N.A.    N.A.       66 %
# Niue                         260            NaN      N.A.    N.A.       46 %
# Tokelau                       10            NaN      N.A.    N.A.        0 %
# Vatican State                  0            NaN      N.A.    N.A.       N.A.
#
#                  WorldShare
# Country
# China               18.47 %
# India               17.70 %
# United States        4.25 %
# Indonesia            3.51 %
# Pakistan             2.83 %
# ...                     ...
# Montserrat           0.00 %
# Falkland Islands     0.00 %
# Niue                 0.00 %
# Tokelau              0.00 %
# Vatican State        0.00 %
#
# [235 rows x 10 columns]

# %%
data.rename(columns={
    "Population(2020)": "Pop",
    "Density(P/Km²)": "Density",
    "Land Area(Km²)": "LandArea",
    "Migrants(net)": "Migrants",
    "UrbanPop %": "UrbanPopPct",
    "WorldShare": "WorldSharePct"
}, inplace=True)

# %%
data
# Out:
#                          Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# China             1439323776       0.39 %    5540090      153   9388211
# India             1380004385       0.99 %   13586631      464   2973190
# United States      331002651       0.59 %    1937734       36   9147420
# Indonesia          273523615       1.07 %    2898047      151   1811570
# Pakistan           220892340       2.00 %    4327022      287    770880
# ...                      ...          ...        ...      ...       ...
# Montserrat              4992       0.06 %          3       50       100
# Falkland Islands        3480       3.05 %        103        0     12170
# Niue                    1626       0.68 %         11        6       260
# Tokelau                 1357       1.27 %         17      136        10
# Vatican State            801       0.25 %          2     2003         0
#
#                   Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# China            -348399.0       1.7      38        61 %       18.47 %
# India            -532687.0       2.2      28        35 %       17.70 %
# United States     954806.0       1.8      38        83 %        4.25 %
# Indonesia         -98955.0       2.3      30        56 %        3.51 %
# Pakistan         -233379.0       3.6      23        35 %        2.83 %
# ...                    ...       ...     ...         ...           ...
# Montserrat             NaN      N.A.    N.A.        10 %        0.00 %
# Falkland Islands       NaN      N.A.    N.A.        66 %        0.00 %
# Niue                   NaN      N.A.    N.A.        46 %        0.00 %
# Tokelau                NaN      N.A.    N.A.         0 %        0.00 %
# Vatican State          NaN      N.A.    N.A.        N.A.        0.00 %
#
# [235 rows x 10 columns]

# %% [markdown]
# ### Daten speichern
#
# Mit den to_... Funktionen können beliebige Dateiformate gespeichert werden
#
# Können auch verwendet werden, um Dateiformate zu ändern (ohne die Daten zu ändern)

# %%
data.to_csv("Data/PopulationDataFastFertig.csv")

# %% [markdown]
# ### Daten analysieren
#
# Erkenntnisse aus den Daten ziehen/mit den Daten selbst arbeiten

# %%
data.head(3)
# Out:
#                       Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# China          1439323776       0.39 %    5540090      153   9388211
# India          1380004385       0.99 %   13586631      464   2973190
# United States   331002651       0.59 %    1937734       36   9147420
#
#                Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# China         -348399.0       1.7      38        61 %       18.47 %
# India         -532687.0       2.2      28        35 %       17.70 %
# United States  954806.0       1.8      38        83 %        4.25 %

# %%
data.tail(3)
# Out:
#                 Pop YearlyChange  NetChange  Density  LandArea  Migrants  \
# Country
# Niue           1626       0.68 %         11        6       260       NaN
# Tokelau        1357       1.27 %         17      136        10       NaN
# Vatican State   801       0.25 %          2     2003         0       NaN
#
#               Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# Niue               N.A.    N.A.        46 %        0.00 %
# Tokelau            N.A.    N.A.         0 %        0.00 %
# Vatican State      N.A.    N.A.        N.A.        0.00 %

# %%
data.head(50)  # Größeren Überblick verschaffen
# Out:
#                        Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# China           1439323776       0.39 %    5540090      153   9388211
# India           1380004385       0.99 %   13586631      464   2973190
# United States    331002651       0.59 %    1937734       36   9147420
# Indonesia        273523615       1.07 %    2898047      151   1811570
# Pakistan         220892340       2.00 %    4327022      287    770880
# Brazil           212559417       0.72 %    1509890       25   8358140
# Nigeria          206139589       2.58 %    5175990      226    910770
# Bangladesh       164689383       1.01 %    1643222     1265    130170
# Russia           145934462       0.04 %      62206        9  16376870
# Mexico           128932753       1.06 %    1357224       66   1943950
# Japan            126476461      -0.30 %    -383840      347    364555
# Ethiopia         114963588       2.57 %    2884858      115   1000000
# Philippines      109581078       1.35 %    1464463      368    298170
# Egypt            102334404       1.94 %    1946331      103    995450
# Vietnam           97338579       0.91 %     876473      314    310070
# DR Congo          89561403       3.19 %    2770836       40   2267050
# Turkey            84339067       1.09 %     909452      110    769630
# Iran              83992949       1.30 %    1079043       52   1628550
# Germany           83783942       0.32 %     266897      240    348560
# Thailand          69799978       0.25 %     174396      137    510890
# United Kingdom    67886011       0.53 %     355839      281    241930
# France            65273511       0.22 %     143783      119    547557
# Italy             60461826      -0.15 %     -88249      206    294140
# Tanzania          59734218       2.98 %    1728755       67    885800
# South Africa      59308690       1.28 %     750420       49   1213090
# Myanmar           54409800       0.67 %     364380       83    653290
# Kenya             53771296       2.28 %    1197323       94    569140
# South Korea       51269185       0.09 %      43877      527     97230
# Colombia          50882891       1.08 %     543448       46   1109500
# Spain             46754778       0.04 %      18002       94    498800
# Uganda            45741007       3.32 %    1471413      229    199810
# Argentina         45195774       0.93 %     415097       17   2736690
# Algeria           43851044       1.85 %     797990       18   2381740
# Sudan             43849260       2.42 %    1036022       25   1765048
# Ukraine           43733762      -0.59 %    -259876       75    579320
# Iraq              40222493       2.32 %     912710       93    434320
# Afghanistan       38928346       2.33 %     886592       60    652860
# Poland            37846611      -0.11 %     -41157      124    306230
# Canada            37742154       0.89 %     331107        4   9093510
# Morocco           36910560       1.20 %     438791       83    446300
# Saudi Arabia      34813871       1.59 %     545343       16   2149690
# Uzbekistan        33469203       1.48 %     487487       79    425400
# Peru              32971854       1.42 %     461401       26   1280000
# Angola            32866272       3.27 %    1040977       26   1246700
# Malaysia          32365999       1.30 %     416222       99    328550
# Mozambique        31255435       2.93 %     889399       40    786380
# Ghana             31072940       2.15 %     655084      137    227540
# Yemen             29825964       2.28 %     664042       56    527970
# Nepal             29136808       1.85 %     528098      203    143350
# Venezuela         28435940      -0.28 %     -79889       32    882050
#
#                 Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# China          -348399.0       1.7      38        61 %       18.47 %
# India          -532687.0       2.2      28        35 %       17.70 %
# United States   954806.0       1.8      38        83 %        4.25 %
# Indonesia       -98955.0       2.3      30        56 %        3.51 %
# Pakistan       -233379.0       3.6      23        35 %        2.83 %
# Brazil           21200.0       1.7      33        88 %        2.73 %
# Nigeria         -60000.0       5.4      18        52 %        2.64 %
# Bangladesh     -369501.0       2.1      28        39 %        2.11 %
# Russia          182456.0       1.8      40        74 %        1.87 %
# Mexico          -60000.0       2.1      29        84 %        1.65 %
# Japan            71560.0       1.4      48        92 %        1.62 %
# Ethiopia         30000.0       4.3      19        21 %        1.47 %
# Philippines     -67152.0       2.6      26        47 %        1.41 %
# Egypt           -38033.0       3.3      25        43 %        1.31 %
# Vietnam         -80000.0       2.1      32        38 %        1.25 %
# DR Congo         23861.0       6.0      17        46 %        1.15 %
# Turkey          283922.0       2.1      32        76 %        1.08 %
# Iran            -55000.0       2.2      32        76 %        1.08 %
# Germany         543822.0       1.6      46        76 %        1.07 %
# Thailand         19444.0       1.5      40        51 %        0.90 %
# United Kingdom  260650.0       1.8      40        83 %        0.87 %
# France           36527.0       1.9      42        82 %        0.84 %
# Italy           148943.0       1.3      47        69 %        0.78 %
# Tanzania        -40076.0       4.9      18        37 %        0.77 %
# South Africa    145405.0       2.4      28        67 %        0.76 %
# Myanmar        -163313.0       2.2      29        31 %        0.70 %
# Kenya           -10000.0       3.5      20        28 %        0.69 %
# South Korea      11731.0       1.1      44        82 %        0.66 %
# Colombia        204796.0       1.8      31        80 %        0.65 %
# Spain            40000.0       1.3      45        80 %        0.60 %
# Uganda          168694.0       5.0      17        26 %        0.59 %
# Argentina         4800.0       2.3      32        93 %        0.58 %
# Algeria         -10000.0       3.1      29        73 %        0.56 %
# Sudan           -50000.0       4.4      20        35 %        0.56 %
# Ukraine          10000.0       1.4      41        69 %        0.56 %
# Iraq              7834.0       3.7      21        73 %        0.52 %
# Afghanistan     -62920.0       4.6      18        25 %        0.50 %
# Poland          -29395.0       1.4      42        60 %        0.49 %
# Canada          242032.0       1.5      41        81 %        0.48 %
# Morocco         -51419.0       2.4      30        64 %        0.47 %
# Saudi Arabia    134979.0       2.3      32        84 %        0.45 %
# Uzbekistan       -8863.0       2.4      28        50 %        0.43 %
# Peru             99069.0       2.3      31        79 %        0.42 %
# Angola            6413.0       5.6      17        67 %        0.42 %
# Malaysia         50000.0       2.0      30        78 %        0.42 %
# Mozambique       -5000.0       4.9      18        38 %        0.40 %
# Ghana           -10000.0       3.9      22        57 %        0.40 %
# Yemen           -30000.0       3.8      20        38 %        0.38 %
# Nepal            41710.0       1.9      25        21 %        0.37 %
# Venezuela      -653249.0       2.3      30        N.A.        0.36 %

# %% [markdown]
# #### Sortieren
# - sort_index
# - sort_values
#
# Bei den Sortierungsmethoden kann mithilfe von ascending=True/False auch die Richtung beeinflusst werden

# %%
data.sort_index()
# Out:
#                       Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# Afghanistan      38928346       2.33 %     886592       60    652860
# Albania           2877797      -0.11 %      -3120      105     27400
# Algeria          43851044       1.85 %     797990       18   2381740
# American Samoa      55191      -0.22 %       -121      276       200
# Andorra             77265       0.16 %        123      164       470
# ...                   ...          ...        ...      ...       ...
# Wallis & Futuna     11239      -1.69 %       -193       80       140
# Western Sahara     597339       2.55 %      14876        2    266000
# Yemen            29825964       2.28 %     664042       56    527970
# Zambia           18383955       2.93 %     522925       25    743390
# Zimbabwe         14862924       1.48 %     217456       38    386850
#
#                  Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# Afghanistan      -62920.0       4.6      18        25 %        0.50 %
# Albania          -14000.0       1.6      36        63 %        0.04 %
# Algeria          -10000.0       3.1      29        73 %        0.56 %
# American Samoa        NaN      N.A.    N.A.        88 %        0.00 %
# Andorra               NaN      N.A.    N.A.        88 %        0.00 %
# ...                   ...       ...     ...         ...           ...
# Wallis & Futuna       NaN      N.A.    N.A.         0 %        0.00 %
# Western Sahara     5582.0       2.4      28        87 %        0.01 %
# Yemen            -30000.0       3.8      20        38 %        0.38 %
# Zambia            -8000.0       4.7      18        45 %        0.24 %
# Zimbabwe        -116858.0       3.6      19        38 %        0.19 %
#
# [235 rows x 10 columns]

# %%
data.sort_index(ascending=False)
# Out:
#                       Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# Zimbabwe         14862924       1.48 %     217456       38    386850
# Zambia           18383955       2.93 %     522925       25    743390
# Yemen            29825964       2.28 %     664042       56    527970
# Western Sahara     597339       2.55 %      14876        2    266000
# Wallis & Futuna     11239      -1.69 %       -193       80       140
# ...                   ...          ...        ...      ...       ...
# Andorra             77265       0.16 %        123      164       470
# American Samoa      55191      -0.22 %       -121      276       200
# Algeria          43851044       1.85 %     797990       18   2381740
# Albania           2877797      -0.11 %      -3120      105     27400
# Afghanistan      38928346       2.33 %     886592       60    652860
#
#                  Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# Zimbabwe        -116858.0       3.6      19        38 %        0.19 %
# Zambia            -8000.0       4.7      18        45 %        0.24 %
# Yemen            -30000.0       3.8      20        38 %        0.38 %
# Western Sahara     5582.0       2.4      28        87 %        0.01 %
# Wallis & Futuna       NaN      N.A.    N.A.         0 %        0.00 %
# ...                   ...       ...     ...         ...           ...
# Andorra               NaN      N.A.    N.A.        88 %        0.00 %
# American Samoa        NaN      N.A.    N.A.        88 %        0.00 %
# Algeria          -10000.0       3.1      29        73 %        0.56 %
# Albania          -14000.0       1.6      36        63 %        0.04 %
# Afghanistan      -62920.0       4.6      18        25 %        0.50 %
#
# [235 rows x 10 columns]

# %%
data.sort_values("LandArea", ascending=False)
# Out:
#                       Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# Russia          145934462       0.04 %      62206        9  16376870
# China          1439323776       0.39 %    5540090      153   9388211
# United States   331002651       0.59 %    1937734       36   9147420
# Canada           37742154       0.89 %     331107        4   9093510
# Brazil          212559417       0.72 %    1509890       25   8358140
# ...                   ...          ...        ...      ...       ...
# Nauru               10824       0.63 %         68      541        20
# Tokelau              1357       1.27 %         17      136        10
# Gibraltar           33691      -0.03 %        -10     3369        10
# Monaco              39242       0.71 %        278    26337         1
# Vatican State         801       0.25 %          2     2003         0
#
#                Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# Russia         182456.0       1.8      40        74 %        1.87 %
# China         -348399.0       1.7      38        61 %       18.47 %
# United States  954806.0       1.8      38        83 %        4.25 %
# Canada         242032.0       1.5      41        81 %        0.48 %
# Brazil          21200.0       1.7      33        88 %        2.73 %
# ...                 ...       ...     ...         ...           ...
# Nauru               NaN      N.A.    N.A.        N.A.        0.00 %
# Tokelau             NaN      N.A.    N.A.         0 %        0.00 %
# Gibraltar           NaN      N.A.    N.A.        N.A.        0.00 %
# Monaco              NaN      N.A.    N.A.        N.A.        0.00 %
# Vatican State       NaN      N.A.    N.A.        N.A.        0.00 %
#
# [235 rows x 10 columns]

# %%
data.sort_values(["Med.Age", "Pop"]).head(30)
# Out:
#                                 Pop YearlyChange  NetChange  Density  \
# Country
# Niger                      24206644       3.84 %     895929       19
# Mali                       20250833       3.02 %     592802       17
# Burundi                    11890784       3.12 %     360204      463
# Somalia                    15893222       2.92 %     450317       25
# Chad                       16425864       3.00 %     478988       13
# Angola                     32866272       3.27 %    1040977       26
# Uganda                     45741007       3.32 %    1471413      229
# DR Congo                   89561403       3.19 %    2770836       40
# Gambia                      2416668       2.94 %      68962      239
# Central African Republic    4829767       1.78 %      84582        8
# Guinea                     13132795       2.83 %     361549       53
# Zambia                     18383955       2.93 %     522925       25
# Malawi                     19129952       2.69 %     501205      203
# Burkina Faso               20903273       2.86 %     581895       76
# Mozambique                 31255435       2.93 %     889399       40
# Afghanistan                38928346       2.33 %     886592       60
# Tanzania                   59734218       2.98 %    1728755       67
# Nigeria                   206139589       2.58 %    5175990      226
# Sao Tome & Principe          219159       1.91 %       4103      228
# Guinea-Bissau               1968001       2.45 %      47079       70
# Eritrea                     3546421       1.41 %      49304       35
# Liberia                     5057681       2.44 %     120307       53
# Congo                       5518087       2.56 %     137579       16
# Sierra Leone                7976983       2.10 %     163768      111
# Togo                        8278724       2.43 %     196358      152
# South Sudan                11193725       1.19 %     131612       18
# Benin                      12123200       2.73 %     322049      108
# Zimbabwe                   14862924       1.48 %     217456       38
# Senegal                    16743927       2.75 %     447563       87
# Côte d'Ivoire              26378274       2.57 %     661730       83
#
#                           LandArea  Migrants Fert.Rate Med.Age UrbanPopPct  \
# Country
# Niger                      1266700    4000.0       7.0      15        17 %
# Mali                       1220190  -40000.0       5.9      16        44 %
# Burundi                      25680    2001.0       5.5      17        14 %
# Somalia                     627340  -40000.0       6.1      17        47 %
# Chad                       1259200    2000.0       5.8      17        23 %
# Angola                     1246700    6413.0       5.6      17        67 %
# Uganda                      199810  168694.0       5.0      17        26 %
# DR Congo                   2267050   23861.0       6.0      17        46 %
# Gambia                       10120   -3087.0       5.3      18        59 %
# Central African Republic    622980  -40000.0       4.8      18        43 %
# Guinea                      245720   -4000.0       4.7      18        39 %
# Zambia                      743390   -8000.0       4.7      18        45 %
# Malawi                       94280  -16053.0       4.3      18        18 %
# Burkina Faso                273600  -25000.0       5.2      18        31 %
# Mozambique                  786380   -5000.0       4.9      18        38 %
# Afghanistan                 652860  -62920.0       4.6      18        25 %
# Tanzania                    885800  -40076.0       4.9      18        37 %
# Nigeria                     910770  -60000.0       5.4      18        52 %
# Sao Tome & Principe            960   -1680.0       4.4      19        74 %
# Guinea-Bissau                28120   -1399.0       4.5      19        45 %
# Eritrea                     101000  -39858.0       4.1      19        63 %
# Liberia                      96320   -5000.0       4.4      19        53 %
# Congo                       341500   -4000.0       4.5      19        70 %
# Sierra Leone                 72180   -4200.0       4.3      19        43 %
# Togo                         54390   -2000.0       4.4      19        43 %
# South Sudan                 610952 -174200.0       4.7      19        25 %
# Benin                       112760   -2000.0       4.9      19        48 %
# Zimbabwe                    386850 -116858.0       3.6      19        38 %
# Senegal                     192530  -20000.0       4.7      19        49 %
# Côte d'Ivoire               318000   -8000.0       4.7      19        51 %
#
#                          WorldSharePct
# Country
# Niger                           0.31 %
# Mali                            0.26 %
# Burundi                         0.15 %
# Somalia                         0.20 %
# Chad                            0.21 %
# Angola                          0.42 %
# Uganda                          0.59 %
# DR Congo                        1.15 %
# Gambia                          0.03 %
# Central African Republic        0.06 %
# Guinea                          0.17 %
# Zambia                          0.24 %
# Malawi                          0.25 %
# Burkina Faso                    0.27 %
# Mozambique                      0.40 %
# Afghanistan                     0.50 %
# Tanzania                        0.77 %
# Nigeria                         2.64 %
# Sao Tome & Principe             0.00 %
# Guinea-Bissau                   0.03 %
# Eritrea                         0.05 %
# Liberia                         0.06 %
# Congo                           0.07 %
# Sierra Leone                    0.10 %
# Togo                            0.11 %
# South Sudan                     0.14 %
# Benin                           0.16 %
# Zimbabwe                        0.19 %
# Senegal                         0.21 %
# Côte d'Ivoire                   0.34 %

# %% [markdown]
# #### Daten filtern
#
# - Normaler Index: Spalten
# - loc: Zeilen
# - iloc: Index Loc

# %%
data.loc["China"]
# Out:
# Pop              1439323776
# YearlyChange         0.39 %
# NetChange           5540090
# Density                 153
# LandArea            9388211
# Migrants          -348399.0
# Fert.Rate               1.7
# Med.Age                  38
# UrbanPopPct            61 %
# WorldSharePct       18.47 %
# Name: China, dtype: object

# %%
data.iloc[0]  # loc[0] ist nicht erlaubt; hier iloc stattdessen verwenden
# Out:
# Pop              1439323776
# YearlyChange         0.39 %
# NetChange           5540090
# Density                 153
# LandArea            9388211
# Migrants          -348399.0
# Fert.Rate               1.7
# Med.Age                  38
# UrbanPopPct            61 %
# WorldSharePct       18.47 %
# Name: China, dtype: object

# %%
# Finde alle Länder die mind. 100m Einwohner haben
data["Pop"] >= 100_000_000
# Out:
# Country
# China                True
# India                True
# United States        True
# Indonesia            True
# Pakistan             True
#                     ...
# Montserrat          False
# Falkland Islands    False
# Niue                False
# Tokelau             False
# Vatican State       False
# Name: Pop, Length: 235, dtype: bool

# %%
data[data["Pop"] >= 100_000_000]
# Out:
#                       Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# China          1439323776       0.39 %    5540090      153   9388211
# India          1380004385       0.99 %   13586631      464   2973190
# United States   331002651       0.59 %    1937734       36   9147420
# Indonesia       273523615       1.07 %    2898047      151   1811570
# Pakistan        220892340       2.00 %    4327022      287    770880
# Brazil          212559417       0.72 %    1509890       25   8358140
# Nigeria         206139589       2.58 %    5175990      226    910770
# Bangladesh      164689383       1.01 %    1643222     1265    130170
# Russia          145934462       0.04 %      62206        9  16376870
# Mexico          128932753       1.06 %    1357224       66   1943950
# Japan           126476461      -0.30 %    -383840      347    364555
# Ethiopia        114963588       2.57 %    2884858      115   1000000
# Philippines     109581078       1.35 %    1464463      368    298170
# Egypt           102334404       1.94 %    1946331      103    995450
#
#                Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# China         -348399.0       1.7      38        61 %       18.47 %
# India         -532687.0       2.2      28        35 %       17.70 %
# United States  954806.0       1.8      38        83 %        4.25 %
# Indonesia      -98955.0       2.3      30        56 %        3.51 %
# Pakistan      -233379.0       3.6      23        35 %        2.83 %
# Brazil          21200.0       1.7      33        88 %        2.73 %
# Nigeria        -60000.0       5.4      18        52 %        2.64 %
# Bangladesh    -369501.0       2.1      28        39 %        2.11 %
# Russia         182456.0       1.8      40        74 %        1.87 %
# Mexico         -60000.0       2.1      29        84 %        1.65 %
# Japan           71560.0       1.4      48        92 %        1.62 %
# Ethiopia        30000.0       4.3      19        21 %        1.47 %
# Philippines    -67152.0       2.6      26        47 %        1.41 %
# Egypt          -38033.0       3.3      25        43 %        1.31 %

# %%
data["China":"Brazil"]  # Hier Zeilen statt Spalten
# Out:
#                       Pop YearlyChange  NetChange  Density  LandArea  \
# Country
# China          1439323776       0.39 %    5540090      153   9388211
# India          1380004385       0.99 %   13586631      464   2973190
# United States   331002651       0.59 %    1937734       36   9147420
# Indonesia       273523615       1.07 %    2898047      151   1811570
# Pakistan        220892340       2.00 %    4327022      287    770880
# Brazil          212559417       0.72 %    1509890       25   8358140
#
#                Migrants Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# China         -348399.0       1.7      38        61 %       18.47 %
# India         -532687.0       2.2      28        35 %       17.70 %
# United States  954806.0       1.8      38        83 %        4.25 %
# Indonesia      -98955.0       2.3      30        56 %        3.51 %
# Pakistan      -233379.0       3.6      23        35 %        2.83 %
# Brazil          21200.0       1.7      33        88 %        2.73 %

# %%
data.loc[:, "Pop":"Density"]  # Mit loc können auch Zeilen + Spalten genommen werden
# Out:
#                          Pop YearlyChange  NetChange  Density
# Country
# China             1439323776       0.39 %    5540090      153
# India             1380004385       0.99 %   13586631      464
# United States      331002651       0.59 %    1937734       36
# Indonesia          273523615       1.07 %    2898047      151
# Pakistan           220892340       2.00 %    4327022      287
# ...                      ...          ...        ...      ...
# Montserrat              4992       0.06 %          3       50
# Falkland Islands        3480       3.05 %        103        0
# Niue                    1626       0.68 %         11        6
# Tokelau                 1357       1.27 %         17      136
# Vatican State            801       0.25 %          2     2003
#
# [235 rows x 4 columns]

# %%
data.loc[:, ("Pop", "WorldSharePct")]  # Nur bestimmte Spalten wählen
# Out:
#                          Pop WorldSharePct
# Country
# China             1439323776       18.47 %
# India             1380004385       17.70 %
# United States      331002651        4.25 %
# Indonesia          273523615        3.51 %
# Pakistan           220892340        2.83 %
# ...                      ...           ...
# Montserrat              4992        0.00 %
# Falkland Islands        3480        0.00 %
# Niue                    1626        0.00 %
# Tokelau                 1357        0.00 %
# Vatican State            801        0.00 %
#
# [235 rows x 2 columns]

# %%
# Finde alle Länder, die mind. 100m Einwohner haben und deren mittleres Alter 25 ist
(data["Pop"] >= 100_000_000) & (data["Med.Age"] == "25")
# Out:
# Country
# China               False
# India               False
# United States       False
# Indonesia           False
# Pakistan            False
#                     ...
# Montserrat          False
# Falkland Islands    False
# Niue                False
# Tokelau             False
# Vatican State       False
# Length: 235, dtype: bool

# %%
data[(data["Pop"] >= 100_000_000) & (data["Med.Age"] == "25")]
# Out:
#                Pop YearlyChange  NetChange  Density  LandArea  Migrants  \
# Country
# Egypt    102334404       1.94 %    1946331      103    995450  -38033.0
#
#         Fert.Rate Med.Age UrbanPopPct WorldSharePct
# Country
# Egypt         3.3      25        43 %        1.31 %

# %%
data["Med.Age"].value_counts()  # Anzahlen pro Inhalt ausgeben
# Out:
# Med.Age
# N.A.    34
# 19      14
# 28      12
# 32      11
# 43      11
# 18      10
# 42      10
# 20       9
# 30       8
# 38       7
# 40       7
# 26       7
# 22       7
# 17       6
# 31       6
# 34       6
# 24       6
# 33       5
# 29       5
# 44       5
# 45       5
# 41       5
# 21       5
# 23       4
# 25       4
# 27       4
# 37       4
# 36       4
# 46       3
# 35       3
# 39       3
# 47       2
# 48       1
# 15       1
# 16       1
# Name: count, dtype: int64

# %% [markdown]
# #### Gruppierung
#
# Datensätze anhand einer Spalte in Gruppen aufteilen
#
# Jeder Datensatz kommt in seine spezifische Gruppe
#
# Auf einzelne Gruppen können dann Analysen gemacht werden

# %%
data.groupby("Med.Age")

# %%
data.groupby("Med.Age").get_group("19")["Pop"].mean()
# Out:
# np.float64(18241182.64285714)

# %%
data.groupby("Med.Age")["Pop"].mean()
# Out:
# Med.Age
# 15      2.420664e+07
# 16      2.025083e+07
# 17      3.539643e+07
# 18      4.148540e+07
# 19      1.824118e+07
# 20      1.939652e+07
# 21      9.621932e+06
# 22      7.686515e+06
# 23      6.028827e+07
# 24      7.213284e+06
# 25      3.304188e+07
# 26      2.510786e+07
# 27      2.088666e+06
# 28      1.398790e+08
# 29      4.693030e+07
# 30      4.894655e+07
# 31      1.847800e+07
# 32      3.284957e+07
# 33      4.789470e+07
# 34      3.726593e+06
# 35      1.595275e+07
# 36      2.161582e+06
# 37      1.772735e+06
# 38      2.590871e+08
# 39      1.120258e+06
# 40      4.277205e+07
# 41      1.942832e+07
# 42      1.717237e+07
# 43      7.631299e+06
# 44      1.210433e+07
# 45      1.320029e+07
# 46      3.480124e+07
# 47      3.041855e+07
# 48      1.264765e+08
# N.A.    3.333179e+04
# Name: Pop, dtype: float64

# %%
for x in data.groupby("Med.Age")["Pop"].mean():
    print(int(x))
# Out:
# 24206644
# 20250833
# 35396425
# 41485399
# 18241182
# 19396523
# 9621932
# 7686515
# 60288272
# 7213284
# 33041880
# 25107858
# 2088666
# 139879041
# 46930304
# 48946550
# 18478003
# 32849571
# 47894699
# 3726593
# 15952753
# 2161581
# 1772735
# 259087065
# 1120258
# 42772052
# 19428317
# 17172367
# 7631298
# 12104325
# 13200286
# 34801235
# 30418545
# 126476461
# 33331
